# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.close("all")

# %%
columns =['i','j','Lambda1','Lambda2','Lambda3','Lambda4','Lambda1Dash','Lambda2Dash','Lambda3Dash','Mu3','Mub','alpha1','alpha2','alpha3','alpha4',\
    'Y1d11','Y1d12','Y1d13','Y1d21','Y1d22','Y1d23','Y2d31','Y2d32','Y2d33','Y1u11','Y1u12','Y1u21','Y1u22','Y2u33','Y1e11','Y1e12','Y1e22','Y1e33',\
    'Y1n11','Y1n12','Y1n22','Y1n33','B11','B12','B21','B22','C13','C23','C31','C32',\
    'imY1d11','imY1d12','imY1d13','imY1d21','imY1d22','imY1d23','imY2d31','imY2d32','imY2d33','imY1u11','imY1u12','imY1u21','imY1u22','imY1e11','imY1e12','imY1e21','imY1e22',\
    'V1','V2','VS','Mhh1','Mhh2','Mhh3','MAh2','MAh3','MHm2','MFv1','MFv2','MFv3','MFv4','MFv5','MFv6',\
    'T_parameter','S_parameter','U_parameter','BRhh2toAh2Ah2']
columns2 = ['HiggsBounds_pass','HBresult','chanel','obsratio','ncomb','HiggsSignal_pass','Pvalue','nobs_tot','nobs_h','nobs_mu','csq_tot','csq_mh','csq_mu']
columns3 = ['RatioBXsgamma','RatioB0ee','RatioBsee','RatioB0mumu','RatioBsmumu','RatioB0tautau',\
    'RatioBstautau','RatioDeltaMd','RatioDeltaMs','RatioRBpmue','RatioRB0mue',\
    'Ratioeps_K','RatioBpKnunu','RatioBppinunu','RatioB0pinunu','RatioB0Knunu',\
    'RatioBRBXsll','RatioBpmunu','RatioBptaunu','RatioBpDlnu','RatioDpmunu','RatioDptaunu',\
    'RatioKLmumu','RatioKLee','RatioKppinunu','RatioKLpinunu','Ratioepsp_over_eps','RatioRmueB0Kll',\
    'RatioRmueBpKll']
columnsNew = columns + columns2 + columns3

# %% [markdown]
# ## Load data

# %%
EWdf = pd.read_csv('EW1T3data.txt',header = None, delimiter = ",",names=columnsNew)
Ddf = pd.read_csv('D1T3data.txt',header = None, delimiter = ",",names=columns)

# %%
EWdf.shape[0] + Ddf.shape[0]
# Out:
# 3000

# %%
EWdf[['HiggsBounds_pass','HBresult','chanel','obsratio','ncomb','HiggsSignal_pass','Pvalue','nobs_tot','nobs_h','nobs_mu','csq_tot','csq_mh','csq_mu']]
# Out:
#      HiggsBounds_pass  HBresult  chanel   obsratio  ncomb  HiggsSignal_pass  \
# 0               False       0.0  1545.0   4.356120    1.0             False
# 1                True       1.0  1257.0   0.049822    1.0             False
# 2               False       0.0  1545.0  13.479400    1.0             False
# 3               False       0.0  1545.0  13.479400    1.0             False
# 4               False       0.0   924.0  14.003700    1.0             False
# ..                ...       ...     ...        ...    ...               ...
# 369             False       0.0  1545.0  22.875700    1.0             False
# 370              True       1.0   612.0   0.161866    1.0             False
# 371             False       0.0   612.0  18.976100    1.0             False
# 372              True       1.0  1545.0   0.138310    1.0             False
# 373              True       1.0  1545.0   0.138310    1.0             False
#
# ...

# %%
EWdf['chanel'].head(20)
# Out:
# 0     1545.0
# 1     1257.0
# 2     1545.0
# 3     1545.0
# 4      924.0
# 5      924.0
# 6      527.0
# 7     1545.0
# 8     1545.0
# 9      922.0
# 10     922.0
# 11     922.0
# 12     611.0
# 13     924.0
# 14     527.0
# 15     527.0
# 16     527.0
# 17     527.0
# 18    1546.0
# 19    1546.0
# Name: chanel, dtype: float64

# %%
EWpHBdf['chanel'].head(50)
# Out:
# 22      1546.0
# 78      1546.0
# 110      721.0
# 160     1545.0
# 173     1545.0
# 220     1545.0
# 226     1545.0
# 229     1545.0
# 278     1545.0
# 284     1545.0
# 290     1545.0
# 322     1545.0
# 359      527.0
# 374      527.0
# 394     1545.0
# 416     1545.0
# 450     1545.0
# 475     1545.0
# 481      466.0
# 512     1545.0
# 536     1545.0
# 544     1545.0
# 566      721.0
# 588      606.0
# 641      466.0
# 649      527.0
# 700      527.0
# 742      721.0
# 797     1545.0
# 840     1545.0
# 919     1545.0
# 924     1545.0
# 932      721.0
# 1000    1545.0
# 1008     527.0
# 1017    1546.0
# 1045     721.0
# 22      1546.0
# 78      1546.0
# 110      721.0
# 160     1545.0
# 173     1545.0
# 220     1545.0
# 226     1545.0
# 229     1545.0
# 278     1545.0
# 284     1545.0
# 290     1545.0
# 322     1545.0
# 359      527.0
# Name: chanel, dtype: float64

# %%
kdf =EWpHBdf[EWpHBdf['chanel'] == 1545.0]

# %%
(kdf.shape[0]/EWpHBdf.shape[0])*100
# Out:
# 53.14685314685315

# %%
ldf =EWpHBdf[EWpHBdf['chanel'] == 721]

# %%
(ldf.shape[0]/EWpHBdf.shape[0])*100
# Out:
# 8.391608391608392

# %%
EWp = EWdf[EWdf['csq_tot'] <= 800 ]
EWp
# Out:
# Empty DataFrame
# Columns: [i, j, Lambda1, Lambda2, Lambda3, Lambda4, Lambda1Dash, Lambda2Dash, Lambda3Dash, Mu3, Mub, alpha1, alpha2, alpha3, alpha4, Y1d11, Y1d12, Y1d13, Y1d21, Y1d22, Y1d23, Y2d31, Y2d32, Y2d33, Y1u11, Y1u12, Y1u21, Y1u22, Y2u33, Y1e11, Y1e12, Y1e22, Y1e33, Y1n11, Y1n12, Y1n22, Y1n33, B11, B12, B21, B22, C13, C23, C31, C32, imY1d11, imY1d12, imY1d13, imY1d21, imY1d22, imY1d23, imY2d31, imY2d32, imY2d33, imY1u11, imY1u12, imY1u21, imY1u22, imY1e11, imY1e12, imY1e21, imY1e22, V1, V2, VS, Mhh1, Mhh2, Mhh3, MAh2, MAh3, MHm2, MFv1, MFv2, MFv3, MFv4, MFv5, MFv6, T_parameter, S_parameter, U_parameter, BRhh2toAh2Ah2, HiggsBounds_pass, HBresult, chanel, obsratio, ncomb, HiggsSignal_pass, Pvalue, nobs_tot, nobs_h, nobs_mu, csq_tot, csq_mh, csq_mu, RatioBXsgamma, RatioB0ee, RatioBsee, RatioB0mumu, RatioBsmumu, RatioB0tautau, ...]
# Index: []
#
# [0 rows x 123 columns]

# %%
Ddf.head(2)
# Out:
#     i  j   Lambda1   Lambda2   Lambda3   Lambda4  Lambda1Dash  Lambda2Dash  \
# 0  11  2  2.065349  0.674637  3.415527 -2.771457     1.054662    -2.231590
# 1  11  3  1.597727  0.865771  3.234030 -2.658022     0.267841     0.255007
#
#    Lambda3Dash          Mu3  ...          MFv1          MFv2          MFv3  \
# 0    -0.395272  -2359.03631  ...  0.000000e+00 -1.344250e-12  2.492386e-12
# 1    -0.198805 -31789.31390  ... -5.048710e-29 -9.743784e-13  2.274177e-12
#
#          MFv4        MFv5        MFv6  T_parameter  S_parameter  U_parameter  \
# 0 -4323.20443 -13200.1173  17523.3218    -0.121119    -0.024731     0.014506
# 1 -4323.20443 -13200.1173  17523.3218    -0.299412    -0.020597     0.007600
#
#    BRhh2toAh2Ah2
# 0       0.919483
# 1       0.981864
#
# [2 rows x 81 columns]

# %%
EWdf[['T_parameter','S_parameter','U_parameter']].plot.box();

# %%
Ddf[['T_parameter','S_parameter','U_parameter']].plot.box();

# %%
EWdf[['i','j']].head(2)
# Out:
#     i  j
# 0  11  1
# 1  11  9

# %% [markdown]
# ## Filter one, pass higgsbounds

# %%
EWpHBdf = EWdf[EWdf['HiggsBounds_pass'] ==True]

# %%
EWpHBdf.shape[0]
# Out:
# 32

# %% [markdown]
# # testing HS data and depemdas on couplings

# %%
Plot_par=['i','j','Lambda1','Lambda2','Lambda3','Lambda4','Lambda1Dash','Lambda2Dash','Lambda3Dash','Mu3','Mub','alpha1','alpha2','alpha3','alpha4',\
 'imY1u11','imY1u12','imY1u21','imY1u22','imY1e11','imY1e12','imY1e21','imY1e22',\
 'V1','V2','VS','Mhh1','Mhh2','Mhh3','MAh2','MAh3','MHm2','MFv1','MFv2','MFv3','MFv4','MFv5','MFv6',\
 'T_parameter','S_parameter','U_parameter','BRhh2toAh2Ah2','RatioBXsgamma','RatioB0ee','RatioBsee','RatioB0mumu','RatioBsmumu','RatioB0tautau',\
    'RatioBstautau','RatioDeltaMd','RatioDeltaMs','RatioRBpmue','RatioRB0mue',\
    'Ratioeps_K','RatioBpKnunu','RatioBppinunu','RatioB0pinunu','RatioB0Knunu',\
    'RatioBRBXsll','RatioBpmunu','RatioBptaunu','RatioBpDlnu','RatioDpmunu','RatioDptaunu',\
    'RatioKLmumu','RatioKLee','RatioKppinunu','RatioKLpinunu','Ratioepsp_over_eps','RatioRmueB0Kll',\
    'RatioRmueBpKll']

# %%
for i in Plot_par:
    if i == 'i' or i== 'j': continue
    else: EWpHBdf.plot.scatter(x=i, y="csq_tot", color='blue',s=10 );
# Out:
# /home/vasileios.vatellis@UA.PT/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %%
EWpHBdf["csq_tot"].hist();

# %%
EWpHBdf[EWpHBdf["csq_tot"]< 860]
# Out:
#       i    j   Lambda1   Lambda2   Lambda3   Lambda4  Lambda1Dash  \
# 450  15  135  3.754967  0.184962  2.969484 -3.250660     0.105212
# 481  15  435  1.744767  0.776028  1.565098 -3.020143     0.650981
# 450  15  135  3.754967  0.184962  2.969484 -3.250660     0.105212
# 481  15  435  1.744767  0.776028  1.565098 -3.020143     0.650981
#
#      Lambda2Dash  Lambda3Dash         Mu3  ...  RatioBpDlnu  RatioDpmunu  \
# 450    -1.384595    -0.103263 -33182.2301  ...          1.0     1.000000
# 481     0.767380    -1.441850 -30169.6655  ...          1.0     1.000008
# 450    -1.384595    -0.103263 -33182.2301  ...          1.0     1.000000
# 481     0.767380    -1.441850 -30169.6655  ...          1.0     1.000008
#
#      RatioDptaunu  RatioKLmumu  RatioKLee  RatioKppinunu  RatioKLpinunu  \
# 450      1.000008          1.0        1.0        1.05369       0.925978
# 481      1.000005          1.0        1.0        0.95504       0.878142
# ...

# %%
test =  EWdf[EWdf['csq_tot'] <= 100 ]
test.shape[0]
# Out:
# 1

# %%
test[['Pvalue']]
# Out:
#        Pvalue
# 297  0.893408

# %%
EWpHBdf[EWpHBdf['csq_tot'] <= 400 ]['csq_tot']
# Out:
# 37     378.815
# 315    306.468
# Name: csq_tot, dtype: float64

# %% [markdown]
# ## Filter two, pass higgsbounds and higgssignals

# %%
EWpHBpHSdf = EWpHBdf[EWpHBdf['Pvalue'] >= 0.05]

# %%
EWpHBpHSdf.shape[0]
# Out:
# 0

# %%
print("total number of points {} number of points pass EWPT, HB, HS {}".format(Ddf.shape[0] + EWdf.shape[0],EWpHBpHSdf.shape[0]))
# Out:
# total number of points 40000 number of points pass EWPT, HB, HS 143

# %% [markdown]
# ## PLots with EWPT, HB and HS

# %%
#set plot colors
color1 = "grey"
color2 = "orange"
color3 = "red"
ss = 10

# %%
ax = Ddf.plot.scatter(x="Mhh2", y="Mhh3", color=color1,s=ss ,label="fail EWPT")
EWdf.plot.scatter(x="Mhh2", y="Mhh3", color=color2,s=ss,label="pass EWPT", ax=ax);
EWpHBpHSdf.plot.scatter(x="Mhh2", y="Mhh3",color=color3,s=ss,label="pass EWPT,HS,HB", ax=ax);

# %%
ax = Ddf.plot.scatter(x="Mhh2", y="MAh2", color=color1,s=ss ,label="fail EWPT")
EWdf.plot.scatter(x="Mhh2", y="MAh2", color=color2,s=ss,label="pass EWPT", ax=ax);
EWpHBpHSdf.plot.scatter(x="Mhh2", y="MAh2",color=color3,s=ss,label="pass EWPT,HS,HB", ax=ax);

# %%
ax = Ddf.plot.scatter(x="Mhh2", y="MAh3", color=color1,s=ss ,label="fail EWPT")
EWdf.plot.scatter(x="Mhh2", y="MAh3", color=color2,s=ss,label="pass EWPT", ax=ax);
EWpHBpHSdf.plot.scatter(x="Mhh2", y="MAh3",color=color3,s=ss,label="pass EWPT,HS,HB", ax=ax);

# %%
ax = Ddf.plot.scatter(x="Mhh2", y="MHm2", color=color1,s=ss ,label="fail EWPT")
EWdf.plot.scatter(x="Mhh2", y="MHm2", color=color2,s=ss,label="pass EWPT", ax=ax);
EWpHBpHSdf.plot.scatter(x="Mhh2", y="MHm2",color=color3,s=ss,label="pass EWPT,HS,HB", ax=ax);

# %%
ax = Ddf.plot.scatter(x="Mhh3", y="MAh2", color=color1,s=ss ,label="fail EWPT")
EWdf.plot.scatter(x="Mhh3", y="MAh2", color=color2,s=ss,label="pass EWPT", ax=ax);
EWpHBpHSdf.plot.scatter(x="Mhh3", y="MAh2",color=color3,s=ss,label="pass EWPT,HS,HB", ax=ax);

# %%
ax = Ddf.plot.scatter(x="Mhh3", y="MAh3", color=color1,s=ss ,label="fail EWPT")
EWdf.plot.scatter(x="Mhh3", y="MAh3", color=color2,s=ss,label="pass EWPT", ax=ax);
EWpHBpHSdf.plot.scatter(x="Mhh3", y="MAh3",color=color3,s=ss,label="pass EWPT,HS,HB", ax=ax);

# %%
ax = Ddf.plot.scatter(x="Mhh3", y="MHm2", color=color1,s=ss ,label="fail EWPT")
EWdf.plot.scatter(x="Mhh3", y="MHm2", color=color2,s=ss,label="pass EWPT", ax=ax);
EWpHBpHSdf.plot.scatter(x="Mhh3", y="MHm2",color=color3,s=ss,label="pass EWPT,HS,HB", ax=ax);

# %%
ax = Ddf.plot.scatter(x="MAh2", y="MAh3", color=color1,s=ss ,label="fail EWPT")
EWdf.plot.scatter(x="MAh2", y="MAh3", color=color2,s=ss ,label="pass EWPT", ax=ax);
EWpHBpHSdf.plot.scatter(x="MAh2", y="MAh3", color=color3,s=ss ,label="pass EWPT,HS,HB", ax=ax);

# %%
ax = Ddf.plot.scatter(x="MAh2", y="MHm2",color=color1,s=ss  ,label="fail EWPT")
EWdf.plot.scatter(x="MAh2", y="MHm2",color=color2,s=ss ,label="pass EWPT", ax=ax);
EWpHBpHSdf.plot.scatter(x="MAh2", y="MHm2",color=color3,s=ss,label="pass EWPT,HS,HB", ax=ax);

# %%
ax = Ddf.plot.scatter(x="MAh3", y="MHm2", color=color1,s=ss ,label="fail EWPT")
EWdf.plot.scatter(x="MAh3", y="MHm2",color=color2,s=ss ,label="pass EWPT", ax=ax);
EWpHBpHSdf.plot.scatter(x="MAh3", y="MHm2",color=color3,s=ss ,label="pass EWPT,HS,HB", ax=ax);

# %%
ax = Ddf.plot.scatter(x='T_parameter', y='S_parameter', color=color1,s=ss ,label="fail EWPT")
EWdf.plot.scatter(x='T_parameter', y='S_parameter',color=color2,s=ss ,label="pass EWPT", ax=ax);
EWpHBpHSdf.plot.scatter(x='T_parameter', y='S_parameter',color=color3,s=ss ,label="pass EWPT,HS,HB", ax=ax);

# %%
EWdf[['Lambda1','Lambda2','Lambda3','Lambda4']].plot.box();
EWpHBpHSdf[['Lambda1','Lambda2','Lambda3','Lambda4']].plot.box();

# %%
print('total points: {}\npoints pass EWPT,HB,HS: {}\n \
{}%'.format(EWdf.shape[0] + Ddf.shape[0],EWpHBpHSdf.shape[0],(EWpHBpHSdf.shape[0]/(EWdf.shape[0] + Ddf.shape[0]))*100 ))
# Out:
# total points: 40000
# points pass EWPT,HB,HS: 143
#  0.3575%
